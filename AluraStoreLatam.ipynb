# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
def facturacion(lista):
  resultado = sum(lista)
  return resultado

def obtener_columna(df,columna):
  lista = df[columna].tolist()
  return lista

precios_tienda1 = tienda['Precio'].tolist()
precios_tienda2 = list(tienda2['Precio'].values)
precios_tienda3 = [float(x) for x in tienda3['Precio'].values]
precios_tienda4 = []
for index, row in tienda4.iterrows():
    precios_tienda4.append(row['Precio'])

# %%
precios_tienda = obtener_columna(tienda, 'Precio')

# %%
type(precios_tienda4)
# Out:
# list

# %%
facturacion_tienda1 = facturacion(precios_tienda1)
facturacion_tienda1
# Out:
# 1150880400.0

# %%
facturacion_tienda2 = facturacion(precios_tienda2)
facturacion_tienda2
# Out:
# np.float64(1116343500.0)

# %%
facturacion_tienda3 = facturacion(precios_tienda3)
facturacion_tienda3
# Out:
# 1098019600.0

# %%
facturacion_tienda4 = facturacion(precios_tienda4)
facturacion_tienda4
# Out:
# 1038375700.0

# %%
tiendas = ['Tienda 1','Tienda 2','Tienda 3', 'Tienda 4']
facturacion = [facturacion_tienda1,facturacion_tienda2, facturacion_tienda3,facturacion_tienda4]

# %%
plt.bar(x=tiendas, height=facturacion)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# La tienda 1 es la que más factura

# %% [markdown]
# # 2. Ventas por categoría

# %%
def obtener_registro_categoria(categorias_tienda, productos_tienda):
    registro_tienda = {}
    for clave, valor in zip(categorias_tienda, productos_tienda):
        if clave not in registro_tienda:
            registro_tienda[clave] = []
        registro_tienda[clave].append(valor)
    return registro_tienda

categorias_tienda1 = tienda['Categoría del Producto'].tolist()
productos_tienda1 = tienda['Producto'].tolist()
registro_tienda1 = obtener_registro_categoria(categorias_tienda1, productos_tienda1)

categorias_tienda2 = tienda2['Categoría del Producto'].tolist()
productos_tienda2 = tienda2['Producto'].tolist()
registro_tienda2 = obtener_registro_categoria(categorias_tienda2, productos_tienda2)

categorias_tienda3 = tienda3['Categoría del Producto'].tolist()
productos_tienda3 = tienda3['Producto'].tolist()
registro_tienda3 = obtener_registro_categoria(categorias_tienda3, productos_tienda3)

categorias_tienda4 = tienda4['Categoría del Producto'].tolist()
productos_tienda4 = tienda4['Producto'].tolist()
registro_tienda4 = obtener_registro_categoria(categorias_tienda4, productos_tienda4)

# %%
def contar_productos_categoria(registro_tienda):
  contador = {}
  for categoria, productos in registro_tienda.items():
    contador[categoria] = len(productos)
  return contador

contador_tienda1 = contar_productos_categoria(registro_tienda1)
contador_tienda2 = contar_productos_categoria(registro_tienda2)
contador_tienda3 = contar_productos_categoria(registro_tienda3)
contador_tienda4 = contar_productos_categoria(registro_tienda4)

# %%
def mostrar_grafico_pastel(conteo, nombre_tienda=''):
    # 1. Ordenar las categorías por cantidad descendente
    categorias_ordenadas = sorted(conteo.items(), key=lambda x: x[1], reverse=True)

    etiquetas = [categoria for categoria, _ in categorias_ordenadas]
    cantidades = [cantidad for _, cantidad in categorias_ordenadas]

    # 2. Crear degradado azul (más oscuro para mayor cantidad)
    cmap = cm.get_cmap('Blues')
    colores = cmap(np.linspace(0.9, 0.3, len(cantidades)))

    # 3. Función personalizada para mostrar porcentaje y cantidad
    def formato_etiqueta(pct, all_vals):
        total = sum(all_vals)
        valor_absoluto = int(round(pct / 100. * total))
        return f'{pct:.1f}%\n({valor_absoluto})'

    # 4. Crear gráfico
    plt.figure(figsize=(6, 6))
    plt.pie(
        cantidades,
        labels=etiquetas,
        colors=colores,
        autopct=lambda pct: formato_etiqueta(pct, cantidades),
        startangle=90
    )
    plt.title(f"Distribución de productos por categoría {nombre_tienda}")
    plt.axis('equal')
    plt.show()

mostrar_grafico_pastel(contador_tienda1,'Tienda 1')
mostrar_grafico_pastel(contador_tienda2,'Tienda 2')
mostrar_grafico_pastel(contador_tienda3,'Tienda 3')
mostrar_grafico_pastel(contador_tienda4,'Tienda 4')
# Out:
# <ipython-input-14-2436507820>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def promedio_calificacion_tienda(calificaciones_tienda):
  resultado = sum(calificaciones_tienda)/len(calificaciones_tienda)
  return(resultado)

calificaciones_tienda1 = tienda['Calificación'].tolist()
calificaciones_tienda2 = tienda2['Calificación'].tolist()
calificaciones_tienda3 = tienda3['Calificación'].tolist()
calificaciones_tienda4 = tienda4['Calificación'].tolist()

promedio_calificacion_tienda1 = promedio_calificacion_tienda(calificaciones_tienda1)
promedio_calificacion_tienda2 = promedio_calificacion_tienda(calificaciones_tienda2)
promedio_calificacion_tienda3 = promedio_calificacion_tienda(calificaciones_tienda3)
promedio_calificacion_tienda4 = promedio_calificacion_tienda(calificaciones_tienda4)

print(promedio_calificacion_tienda1)
print(promedio_calificacion_tienda2)
print(promedio_calificacion_tienda3)
print(promedio_calificacion_tienda4)

promedios_calificacion = [promedio_calificacion_tienda1, promedio_calificacion_tienda2, promedio_calificacion_tienda3, promedio_calificacion_tienda4]

plt.bar(x=tiendas, height=promedios_calificacion)
plt.show
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.9957591178965224
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def registro_productos(productos_tienda):
    registro_tienda_productos = {}
    for producto in productos_tienda:
        if producto in registro_tienda_productos:
            registro_tienda_productos[producto] += 1
        else:
            registro_tienda_productos[producto] = 1
    return registro_tienda_productos


registro_tienda1_productos = registro_productos(productos_tienda1)
registro_tienda2_productos = registro_productos(productos_tienda2)
registro_tienda3_productos = registro_productos(productos_tienda3)
registro_tienda4_productos = registro_productos(productos_tienda4)

# %%
def graficar_tienda(nombre_tienda, registro_productos):

    # Ordenar productos por cantidad (de menor a mayor)
    registro_ordenado = dict(sorted(registro_productos.items(), key=lambda item: item[1]))

    productos = list(registro_ordenado.keys())
    cantidades = list(registro_ordenado.values())

    # Crear gráfico
    plt.figure(figsize=(10, max(6, len(productos) * 0.3)))  # Ajusta la altura según la cantidad de productos
    plt.barh(productos, cantidades, color='cornflowerblue')
    plt.xlabel('Cantidad')
    plt.title(f'Cantidad por producto - {nombre_tienda}')
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

graficar_tienda('Tienda 1', registro_tienda1_productos)
graficar_tienda('Tienda 2', registro_tienda2_productos)
graficar_tienda('Tienda 3', registro_tienda3_productos)
graficar_tienda('Tienda 4', registro_tienda4_productos)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def promedio_envio_tienda(costos_envio_tienda):
  resultado = sum(costos_envio_tienda)/len(costos_envio_tienda)
  return(resultado)

costos_envio_tienda1 = tienda['Costo de envío'].tolist()
costos_envio_tienda2 = tienda2['Costo de envío'].tolist()
costos_envio_tienda3 = tienda3['Costo de envío'].tolist()
costos_envio_tienda4 = tienda4['Costo de envío'].tolist()

promedio_envio_tienda1 = promedio_envio_tienda(costos_envio_tienda1)
promedio_envio_tienda2 = promedio_envio_tienda(costos_envio_tienda2)
promedio_envio_tienda3 = promedio_envio_tienda(costos_envio_tienda3)
promedio_envio_tienda4 = promedio_envio_tienda(costos_envio_tienda4)
print(promedio_envio_tienda1)
print(promedio_envio_tienda2)
print(promedio_envio_tienda3)
print(promedio_envio_tienda4)

promedios_envio = [promedio_envio_tienda1, promedio_envio_tienda2, promedio_envio_tienda3, promedio_envio_tienda4]

plt.bar(x=tiendas, height=promedios_envio)
plt.show
# Out:
# 26018.60958033065
# 25216.235693090293
# 24805.680373039424
# 23459.457167090754
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Informe Final**
#
# En este pryecto se nos proporcionan datos de 4 tiendas con diferentes productos, el objetivo del presenta analisis es determinar que tienda tiene las peores estadisticas y es menos eficiente para posteriormete realizar la venta de dicha tienda. Para apoyarnos en el análisis matemático usamos Python y la libreria matplotlib respectivamente.
#
# 1. Analisis de facturación
